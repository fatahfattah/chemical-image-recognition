# %%
import os
import pandas
from shutil import move

# %%
with open('Image_countStructures.txt', 'r') as f:
    data = [x.split('\t') for x in  f.read().split('\n')[1:]]
    

if not os.path.isdir('I20210302/I20210302/dataset/manychemical'):
    os.makedirs( 'I20210302/I20210302/dataset/manychemical')

# %%
items = os.listdir('I20210302/I20210302/dataset/chemical')
for image, cnt in data:
#     print(image+'.TIF')
    
    if image+'.TIF' in items and cnt > '1':
        print(image, cnt)

        move(os.path.join('I20210302/I20210302/dataset/chemical', image+'.TIF'), 'I20210302/I20210302/dataset/manychemical')
# Out:
# US10932466-20210302-C00004 2
# US10932466-20210302-C00006 2
# US10932467-20210302-C00002 4
# US10932467-20210302-C00004 4
# US10932901-20210302-C00001 3
# US10932901-20210302-C00004 3
# US10932995-20210302-C00013 7
# US10932995-20210302-C00018 7
# US10932995-20210302-C00023 4
# US10932995-20210302-C00024 2
# US10932995-20210302-C00025 5
# US10932995-20210302-C00046 7
# US10932995-20210302-C00047 7
# US10932995-20210302-C00048 4
# US10933005-20210302-C00006 2
# US10933008-20210302-C00004 6
# US10933008-20210302-C00005 3
# US10933008-20210302-C00007 2
# US10933008-20210302-C00009 2
# US10933008-20210302-C00012 6
# US10933011-20210302-C00001 4
# US10933033-20210302-C00001 3
# US10933033-20210302-C00002 3
# US10933033-20210302-C00003 3
# US10933033-20210302-C00004 3
# US10933033-20210302-C00005 3
# US10933033-20210302-C00006 3
# US10933034-20210302-C00003 10
# US10933034-20210302-C00004 9
# US10933034-20210302-C00005 2
# US10933034-20210302-C00006 4
# US10933036-20210302-C00012 2
# ...

# %%
path = "I20210302/I20210302/dataset"
target_path = '/home/fatah/Desktop/cnc_dataset'
for c in ["chemical", "manychemical"]:
    for img in os.listdir(os.path.join(path, c)):
        move(os.path.join(path, c, img), os.path.join(target_path, c, img))
