# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import seaborn as sns
import pandas as pd

import random
random.seed(42)

import matplotlib.pyplot as plt
import numpy as np

from tqdm import tqdm

# %%
image_size = (299, 299)
batch_size = 8
data_dir = '/home/fatah/Desktop/cnc'

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Resize(image_size)])

dataset = torchvision.datasets.ImageFolder(data_dir,
                                            transform=transform)


indices = np.arange(len(dataset))
train_indices, test_indices = train_test_split(indices, train_size= 8000*2, test_size= 2000*2, stratify= dataset.targets)

trainset = Subset(dataset, train_indices)
testset = Subset(dataset, test_indices)


train_data_loader = DataLoader(trainset,
                                                batch_size=batch_size,
                                                shuffle=True)

test_data_loader = DataLoader(testset,
                                                batch_size=batch_size,
                                                shuffle=False)

classes = ('chemical', 'nonchemical')

# %%
from collections import Counter
train_classes = [classes[dataset.targets[i]] for i in test_indices]
Counter(train_classes)
# Out:
# Counter({'nonchemical': 2000, 'chemical': 2000})

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_data_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# nonchemical nonchemical chemical chemical nonchemical nonchemical chemical chemical

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
model = torch.hub.load('pytorch/vision:v0.9.0', 'inception_v3', pretrained=False)
model.fc = nn.Linear(2048, 2)
model.to(device)
# Out:
# Using cache found in /home/fatah/.cache/torch/hub/pytorch_vision_v0.9.0
# /home/fatah/anaconda3/envs/elsevier/lib/python3.8/site-packages/torchvision/models/inception.py:80: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn('The default weight initialization of inception_v3 will be changed in future releases of '
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
transform = transforms.Compose(
    [
     transforms.RandomHorizontalFlip(),
     transforms.RandomVerticalFlip(),
     transforms.RandomAdjustSharpness(0),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

epochs = 10

print(f"Starting model training for {epochs} epochs...")
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch+1}...")
    running_loss = 0.0
    for i, data in enumerate(train_data_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        inputs = transform(inputs)
#         # Zero the parameter gradients
        optimizer.zero_grad()
        
        outputs, aux = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if i % 100 == 99:    # print every n mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 100))
        running_loss = 0.0

PATH = './models/cnc_small.pth'
torch.save(model.state_dict(), PATH)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Starting model training for 10 epochs...
# Epoch: 1...
# [1,   100] loss: 0.005
# [1,   200] loss: 0.005
# [1,   300] loss: 0.003
# [1,   400] loss: 0.009
# [1,   500] loss: 0.001
# [1,   600] loss: 0.007
# [1,   700] loss: 0.003
# [1,   800] loss: 0.004
# [1,   900] loss: 0.001
# [1,  1000] loss: 0.001
# [1,  1100] loss: 0.003
# [1,  1200] loss: 0.000
# [1,  1300] loss: 0.001
# [1,  1400] loss: 0.009
# [1,  1500] loss: 0.003
# [1,  1600] loss: 0.003
# [1,  1700] loss: 0.000
# [1,  1800] loss: 0.000
# [1,  1900] loss: 0.000
#  10%|█         | 1/10 [08:02<1:12:18, 482.01s/it]
# [1,  2000] loss: 0.000
# Epoch: 2...
# [2,   100] loss: 0.000
# [2,   200] loss: 0.003
# [2,   300] loss: 0.002
# [2,   400] loss: 0.000
# [2,   500] loss: 0.002
# [2,   600] loss: 0.004
# [2,   700] loss: 0.000
# [2,   800] loss: 0.001
# [2,   900] loss: 0.003
# [2,  1000] loss: 0.007
# [2,  1100] loss: 0.010
# [2,  1200] loss: 0.003
# [2,  1300] loss: 0.003
# [2,  1400] loss: 0.001
# [2,  1500] loss: 0.003
# [2,  1600] loss: 0.001
# [2,  1700] loss: 0.000
# [2,  1800] loss: 0.009
# [2,  1900] loss: 0.000
#  20%|██        | 2/10 [16:01<1:04:04, 480.54s/it]
# [2,  2000] loss: 0.002
# Epoch: 3...
# [3,   100] loss: 0.000
# [3,   200] loss: 0.000
# [3,   300] loss: 0.001
# [3,   400] loss: 0.005
# [3,   500] loss: 0.000
# [3,   600] loss: 0.001
# [3,   700] loss: 0.000
# [3,   800] loss: 0.000
# [3,   900] loss: 0.001
# [3,  1000] loss: 0.000
# [3,  1100] loss: 0.000
# [3,  1200] loss: 0.002
# [3,  1300] loss: 0.000
# [3,  1400] loss: 0.001
# [3,  1500] loss: 0.001
# [3,  1600] loss: 0.000
# [3,  1700] loss: 0.000
# [3,  1800] loss: 0.000
# [3,  1900] loss: 0.003
#  30%|███       | 3/10 [24:02<56:04, 480.57s/it]
# [3,  2000] loss: 0.000
# Epoch: 4...
# [4,   100] loss: 0.002
# [4,   200] loss: 0.002
# [4,   300] loss: 0.000
# [4,   400] loss: 0.000
# [4,   500] loss: 0.000
# [4,   600] loss: 0.000
# [4,   700] loss: 0.004
# [4,   800] loss: 0.000
# [4,   900] loss: 0.002
# [4,  1000] loss: 0.000
# [4,  1100] loss: 0.000
# [4,  1200] loss: 0.000
# [4,  1300] loss: 0.001
# [4,  1400] loss: 0.001
# [4,  1500] loss: 0.000
# [4,  1600] loss: 0.000
# [4,  1700] loss: 0.006
# [4,  1800] loss: 0.000
# [4,  1900] loss: 0.000
#  40%|████      | 4/10 [32:01<48:01, 480.17s/it]
# [4,  2000] loss: 0.004
# Epoch: 5...
# [5,   100] loss: 0.001
# [5,   200] loss: 0.003
# [5,   300] loss: 0.003
# [5,   400] loss: 0.000
# [5,   500] loss: 0.001
# [5,   600] loss: 0.000
# [5,   700] loss: 0.000
# [5,   800] loss: 0.000
# [5,   900] loss: 0.000
# [5,  1000] loss: 0.000
# [5,  1100] loss: 0.000
# [5,  1200] loss: 0.000
# [5,  1300] loss: 0.000
# [5,  1400] loss: 0.000
# [5,  1500] loss: 0.012
# [5,  1600] loss: 0.001
# [5,  1700] loss: 0.001
# [5,  1800] loss: 0.000
# [5,  1900] loss: 0.000
#  50%|█████     | 5/10 [40:06<40:08, 481.77s/it]
# [5,  2000] loss: 0.000
# Epoch: 6...
# [6,   100] loss: 0.000
# [6,   200] loss: 0.000
# [6,   300] loss: 0.000
# [6,   400] loss: 0.000
# [6,   500] loss: 0.000
# [6,   600] loss: 0.001
# [6,   700] loss: 0.000
# [6,   800] loss: 0.003
# [6,   900] loss: 0.000
# [6,  1000] loss: 0.001
# [6,  1100] loss: 0.000
# [6,  1200] loss: 0.000
# [6,  1300] loss: 0.000
# [6,  1400] loss: 0.000
# [6,  1500] loss: 0.001
# [6,  1600] loss: 0.000
# [6,  1700] loss: 0.001
# [6,  1800] loss: 0.000
# [6,  1900] loss: 0.000
#  60%|██████    | 6/10 [48:06<32:05, 481.26s/it]
# [6,  2000] loss: 0.000
# Epoch: 7...
# [7,   100] loss: 0.006
# [7,   200] loss: 0.000
# [7,   300] loss: 0.003
# [7,   400] loss: 0.002
# [7,   500] loss: 0.000
# [7,   600] loss: 0.000
# [7,   700] loss: 0.000
# [7,   800] loss: 0.000
# [7,   900] loss: 0.000
# [7,  1000] loss: 0.007
# [7,  1100] loss: 0.001
# [7,  1200] loss: 0.000
# [7,  1300] loss: 0.002
# [7,  1400] loss: 0.000
# [7,  1500] loss: 0.002
# [7,  1600] loss: 0.000
# [7,  1700] loss: 0.000
# [7,  1800] loss: 0.000
# [7,  1900] loss: 0.001
#  70%|███████   | 7/10 [56:07<24:03, 481.03s/it]
# [7,  2000] loss: 0.000
# Epoch: 8...
# [8,   100] loss: 0.000
# [8,   200] loss: 0.002
# [8,   300] loss: 0.000
# [8,   400] loss: 0.000
# [8,   500] loss: 0.000
# [8,   600] loss: 0.001
# [8,   700] loss: 0.000
# [8,   800] loss: 0.003
# [8,   900] loss: 0.001
# [8,  1000] loss: 0.000
# [8,  1100] loss: 0.000
# [8,  1200] loss: 0.000
# [8,  1300] loss: 0.000
# [8,  1400] loss: 0.000
# [8,  1500] loss: 0.000
# [8,  1600] loss: 0.002
# [8,  1700] loss: 0.001
# [8,  1800] loss: 0.000
# [8,  1900] loss: 0.000
#  80%|████████  | 8/10 [1:04:07<16:01, 480.94s/it]
# [8,  2000] loss: 0.000
# Epoch: 9...
# [9,   100] loss: 0.000
# [9,   200] loss: 0.001
# [9,   300] loss: 0.001
# [9,   400] loss: 0.001
# [9,   500] loss: 0.001
# [9,   600] loss: 0.000
# [9,   700] loss: 0.000
# [9,   800] loss: 0.000
# [9,   900] loss: 0.000
# [9,  1000] loss: 0.002
# [9,  1100] loss: 0.000
# [9,  1200] loss: 0.000
# [9,  1300] loss: 0.000
# [9,  1400] loss: 0.001
# [9,  1500] loss: 0.000
# [9,  1600] loss: 0.001
# [9,  1700] loss: 0.003
# [9,  1800] loss: 0.000
# [9,  1900] loss: 0.000
#  90%|█████████ | 9/10 [1:12:08<08:00, 480.99s/it]
# [9,  2000] loss: 0.002
# Epoch: 10...
# [10,   100] loss: 0.000
# [10,   200] loss: 0.000
# [10,   300] loss: 0.000
# [10,   400] loss: 0.002
# [10,   500] loss: 0.000
# [10,   600] loss: 0.000
# [10,   700] loss: 0.000
# [10,   800] loss: 0.000
# [10,   900] loss: 0.000
# [10,  1000] loss: 0.000
# [10,  1100] loss: 0.000
# [10,  1200] loss: 0.000
# [10,  1300] loss: 0.000
# [10,  1400] loss: 0.000
# [10,  1500] loss: 0.000
# [10,  1600] loss: 0.000
# [10,  1700] loss: 0.000
# [10,  1800] loss: 0.000
# [10,  1900] loss: 0.000
# 100%|██████████| 10/10 [1:20:12<00:00, 481.21s/it]
# [10,  2000] loss: 0.000

# %%
model = torch.hub.load('pytorch/vision:v0.9.0', 'inception_v3', pretrained=False)
model.fc = nn.Linear(2048, 2)
PATH = './models/cnc_small.pth'
model.load_state_dict(torch.load(PATH))
model.eval()
# Out:
# Using cache found in /home/fatah/.cache/torch/hub/pytorch_vision_v0.9.0
# /home/fatah/anaconda3/envs/elsevier/lib/python3.8/site-packages/torchvision/models/inception.py:80: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn('The default weight initialization of inception_v3 will be changed in future releases of '
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
transform = transforms.Compose(
    [
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

outs = []
true_labels = []
class_correct = list(0. for i in range(len(classes)))
class_total = list(0. for i in range(len(classes)))
with torch.no_grad():
    for data in test_data_loader:
        images, labels = data
        images = transform(images)
        true_labels.extend(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        outs.extend(predicted)
        c = (predicted == labels).squeeze()
        for i in range(batch_size):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(len(classes)):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))

print(classification_report(true_labels, outs))
# Out:
# Accuracy of chemical : 94 %
# Accuracy of nonchemical : 99 %
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97      2000
#            1       0.94      1.00      0.97      2000
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000

# %%
df_cm = pd.DataFrame(confusion_matrix(true_labels, outs, normalize='true'), 
                      index = classes,
                      columns = classes)

plt.figure(figsize = (10,10))
sns.heatmap(df_cm, annot=True)

# %%
dataiter = iter(test_data_loader)
images, labels = dataiter.next()

# print images
# imshow(torchvision.utils.make_grid(images, scale_each=True), )
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))

f, axarr = plt.subplots(1, 8, figsize=(299,299))
for i, img in enumerate(images):
    axarr[i].imshow(img.permute(1, 2, 0).numpy())
    
_, predicted = torch.max(model(images), 1)
print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(batch_size)))

# %%
import os
from PIL import Image

image_size = (299, 299)
path = "/home/fatah/Desktop/EP_PNG"

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Resize(image_size),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

preds = {}

for img in sorted(os.listdir(path))[:500]:
    image = Image.open(os.path.join(path, img))
    image = image.convert('RGB')
    image = transform(image)
    with torch.no_grad():
        outputs = model(image[None, ...])
        aux,predicted = torch.max(outputs, 1)
        prediction = classes[predicted[0]]
        preds.setdefault(prediction, []).append(img)
        print(img,  prediction)
# Out:
# EP2947085A1_00082.PNG chemical
# EP2947085A1_00083.PNG chemical
# EP2947085A1_00084.PNG chemical
# EP2947085A1_00085.PNG chemical
# EP2947085A1_00086.PNG chemical
# EP2947085A1_00087.PNG chemical
# EP2947085A1_00088.PNG chemical
# EP2947085A1_00089.PNG chemical
# EP2947085A1_00090.PNG chemical
# EP2947085A1_00091.PNG chemical
# EP2947085A1_00092.PNG chemical
# EP2947085A1_00093.PNG chemical
# EP2947085A1_00094.PNG chemical
# EP2947085A1_00095.PNG chemical
# EP2947085A1_00096.PNG chemical
# EP2947085A1_00097.PNG chemical
# EP2947085A1_00098.PNG chemical
# EP2947085A1_00099.PNG chemical
# EP2947085A1_00100.PNG chemical
# EP2947085A1_00101.PNG chemical
# EP2947085A1_00102.PNG chemical
# EP2947085A1_00103.PNG chemical
# EP2947085A1_00104.PNG chemical
# EP2947085A1_00105.PNG chemical
# EP2947085A1_00106.PNG chemical
# EP2947085A1_00107.PNG chemical
# EP2947085A1_00108.PNG chemical
# EP2947085A1_00109.PNG chemical
# EP2947085A1_00110.PNG chemical
# EP2947085A1_00111.PNG chemical
# EP2947085A1_00112.PNG chemical
# EP2947085A1_00113.PNG chemical
# EP2947085A1_00114.PNG chemical
# EP2947085A1_00115.PNG chemical
# EP2947085A1_00116.PNG chemical
# EP2947085A1_00117.PNG chemical
# EP2947085A1_00118.PNG chemical
# EP2947085A1_00119.PNG chemical
# EP2947085A1_00120.PNG chemical
# EP2947085A1_00121.PNG chemical
# EP2947085A1_00122.PNG chemical
# EP2947085A1_00123.PNG chemical
# EP2947085A1_00124.PNG chemical
# EP2947085A1_00125.PNG chemical
# EP2947085A1_00126.PNG chemical
# EP2947085A1_00127.PNG chemical
# EP2947085A1_00128.PNG chemical
# EP2947085A1_00129.PNG chemical
# EP2947085A1_00130.PNG chemical
# EP2947085A1_00131.PNG chemical
# EP2947085A1_00132.PNG chemical
# EP2947085A1_00133.PNG chemical
# EP2947085A1_00134.PNG chemical
# EP2947085A1_00135.PNG chemical
# EP2947085A1_00136.PNG chemical
# EP2947085A1_00137.PNG chemical
# EP2947085A1_00138.PNG chemical
# EP2947085A1_00139.PNG chemical
# EP2947085A1_00140.PNG chemical
# EP2947085A1_00141.PNG chemical
# EP2947085A1_00142.PNG chemical
# EP2947085A1_00143.PNG chemical
# EP2947085A1_00144.PNG chemical
# EP2947085A1_00145.PNG chemical
# EP2947085A1_00146.PNG chemical
# EP2947085A1_00147.PNG chemical
# EP2947085A1_00148.PNG chemical
# EP2947085A1_00149.PNG nonchemical
# EP2947085A1_00150.PNG chemical
# EP2947085A1_00151.PNG chemical
# EP2947085A1_00152.PNG chemical
# EP2947085A1_00153.PNG chemical
# EP2947085A1_00154.PNG chemical
# EP2947085A1_00155.PNG chemical
# EP2947085A1_00156.PNG chemical
# EP2947085A1_00157.PNG chemical
# EP2947085A1_00158.PNG chemical
# EP2947085A1_00159.PNG chemical
# EP2947085A1_00160.PNG chemical
# EP2947085A1_00161.PNG chemical
# EP2947085A1_00162.PNG chemical
# EP2947085A1_00163.PNG chemical
# EP2947085A1_00164.PNG chemical
# EP2947085A1_00165.PNG chemical
# EP2947085A1_00166.PNG chemical
# EP2947085A1_00167.PNG chemical
# EP2947085A1_00168.PNG chemical
# EP2947085A1_00169.PNG chemical
# EP2947085A1_00170.PNG nonchemical
# EP2947085A1_00171.PNG nonchemical
# EP2947085A1_00172.PNG chemical
# EP2947085A1_00173.PNG nonchemical
# EP2947085A1_00174.PNG nonchemical
# EP2947085A1_00175.PNG nonchemical
# EP2947085A1_00176.PNG nonchemical
# EP2947085A1_00177.PNG nonchemical
# EP2947085A1_00178.PNG chemical
# EP2947085A1_00179.PNG chemical
# EP2947085A1_00180.PNG chemical
# EP2947085A1_00181.PNG chemical
# EP2947085A1_00182.PNG chemical
# EP2947085A1_00183.PNG chemical
# EP2947085A1_00184.PNG chemical
# EP2947085A1_00185.PNG chemical
# EP2947085A1_00186.PNG chemical
# EP2947085A1_00187.PNG chemical
# EP2947085A1_00188.PNG chemical
# EP2947085A1_00189.PNG chemical
# EP2947085A1_00190.PNG chemical
# EP2947085A1_00191.PNG chemical
# EP2947085A1_00192.PNG chemical
# EP2947085A1_00193.PNG chemical
# EP2947085A1_00194.PNG chemical
# EP2947085A1_00195.PNG chemical
# EP2947085A1_00196.PNG chemical
# EP2947085A1_00197.PNG chemical
# EP2947085A1_00198.PNG chemical
# EP2947085A1_00199.PNG chemical
# EP2947085A1_00200.PNG chemical
# EP2947085A1_00201.PNG chemical
# EP2947085A1_00202.PNG chemical
# EP2947085A1_00203.PNG chemical
# EP2947085A1_00204.PNG chemical
# EP2947085A1_00205.PNG chemical
# EP2947085A1_00206.PNG chemical
# EP2947085A1_00207.PNG chemical
# EP2947085A1_00208.PNG chemical
# EP2947085A1_00209.PNG chemical
# EP2947085A1_00210.PNG chemical
# EP2947085A1_00211.PNG chemical
# EP2947085A1_00212.PNG chemical
# EP2947085A1_00213.PNG chemical
# EP2947085A1_00214.PNG chemical
# EP2947085A1_00215.PNG chemical
# EP2947085A1_00216.PNG chemical
# EP2947085A1_00217.PNG chemical
# EP2947085A1_00218.PNG chemical
# EP2947085A1_00219.PNG nonchemical
# EP2947085A1_00220.PNG nonchemical
# EP2947085A1_00221.PNG nonchemical
# EP2947085A1_00222.PNG nonchemical
# EP2947086A1_00001.PNG chemical
# EP2947086A1_00002.PNG nonchemical
# EP2947086A1_00003.PNG chemical
# EP2947086A1_00004.PNG nonchemical
# EP2947086A1_00005.PNG chemical
# EP2947086A1_00006.PNG nonchemical
# EP2947086A1_00007.PNG chemical
# EP2947086A1_00008.PNG chemical
# EP2947086A1_00009.PNG nonchemical
# EP2947086A1_00010.PNG nonchemical
# EP2947086A1_00011.PNG nonchemical
# EP2947086A1_00012.PNG nonchemical
# EP2947086A1_00013.PNG nonchemical
# EP2947086A1_00014.PNG chemical
# EP2947086A1_00015.PNG nonchemical
# EP2947086A1_00016.PNG chemical
# EP2947086A1_00017.PNG nonchemical
# EP2947086A1_00018.PNG chemical
# EP2947086A1_00019.PNG chemical
# EP2947086A1_00020.PNG chemical
# EP2947086A1_00021.PNG chemical
# EP2947086A1_00022.PNG chemical
# EP2947086A1_00023.PNG chemical
# EP2947086A1_00024.PNG chemical
# EP2947086A1_00025.PNG chemical
# EP2947086A1_00026.PNG chemical
# EP2947086A1_00027.PNG chemical
# EP2947086A1_00028.PNG chemical
# EP2947086A1_00029.PNG chemical
# EP2947086A1_00030.PNG chemical
# EP2947086A1_00031.PNG chemical
# EP2947086A1_00032.PNG chemical
# EP2947086A1_00033.PNG chemical
# EP2947086A1_00034.PNG chemical
# EP2947086A1_00035.PNG chemical
# EP2947086A1_00036.PNG chemical
# EP2947086A1_00037.PNG chemical
# EP2947086A1_00038.PNG chemical
# EP2947086A1_00039.PNG chemical
# EP2947086A1_00040.PNG chemical
# EP2947086A1_00041.PNG chemical
# EP2947086A1_00042.PNG chemical
# EP2947086A1_00043.PNG chemical
# EP2947086A1_00044.PNG chemical
# EP2947086A1_00045.PNG chemical
# EP2947086A1_00046.PNG chemical
# EP2947086A1_00047.PNG chemical
# EP2947086A1_00048.PNG chemical
# EP2947086A1_00049.PNG chemical
# EP2947086A1_00050.PNG chemical
# EP2947086A1_00051.PNG chemical
# EP2947086A1_00052.PNG chemical
# EP2947086A1_00053.PNG chemical
# EP2947086A1_00054.PNG chemical
# EP2947086A1_00055.PNG chemical
# EP2947086A1_00056.PNG chemical
# EP2947086A1_00057.PNG chemical
# EP2947086A1_00058.PNG chemical
# EP2947086A1_00059.PNG chemical
# EP2947086A1_00060.PNG chemical
# EP2947086A1_00061.PNG chemical
# EP2947086A1_00062.PNG chemical
# EP2947086A1_00063.PNG chemical
# EP2947086A1_00064.PNG chemical
# EP2947086A1_00065.PNG chemical
# EP2947086A1_00066.PNG chemical
# EP2947086A1_00067.PNG chemical
# EP2947086A1_00068.PNG chemical
# EP2947086A1_00069.PNG chemical
# EP2947086A1_00070.PNG chemical
# EP2947086A1_00071.PNG chemical
# EP2947086A1_00072.PNG chemical
# EP2947086A1_00073.PNG chemical
# EP2947086A1_00074.PNG chemical
# EP2947086A1_00075.PNG chemical
# EP2947086A1_00076.PNG chemical
# EP2947086A1_00077.PNG chemical
# EP2947086A1_00078.PNG chemical
# EP2947086A1_00079.PNG chemical
# EP2947086A1_00080.PNG chemical
# EP2947086A1_00081.PNG chemical
# EP2947086A1_00082.PNG chemical
# EP2947086A1_00083.PNG chemical
# EP2947086A1_00084.PNG chemical
# EP2947086A1_00085.PNG chemical
# EP2947086A1_00086.PNG chemical
# EP2947086A1_00087.PNG chemical
# EP2947086A1_00088.PNG chemical
# EP2947086A1_00089.PNG chemical
# EP2947086A1_00090.PNG chemical
# EP2947086A1_00091.PNG chemical
# EP2947086A1_00092.PNG chemical
# EP2947086A1_00093.PNG chemical
# EP2947086A1_00094.PNG chemical
# EP2947086A1_00095.PNG chemical
# EP2947086A1_00096.PNG chemical
# EP2947086A1_00097.PNG chemical
# EP2947086A1_00098.PNG chemical
# EP2947086A1_00099.PNG chemical
# EP2947086A1_00100.PNG chemical
# EP2947086A1_00101.PNG chemical
# EP2947086A1_00102.PNG chemical
# EP2947086A1_00103.PNG chemical
# EP2947086A1_00104.PNG chemical
# EP2947086A1_00105.PNG chemical
# EP2947086A1_00106.PNG chemical
# EP2947086A1_00107.PNG chemical
# EP2947086A1_00108.PNG chemical
# EP2947086A1_00109.PNG chemical
# EP2947086A1_00110.PNG chemical
# EP2947086A1_00111.PNG chemical
# EP2947086A1_00112.PNG nonchemical
# EP2947086A1_00113.PNG nonchemical
# EP2947086A1_00114.PNG nonchemical
# EP2947086A1_00115.PNG chemical
# EP2947086A1_00116.PNG chemical
# EP2947093A1_00001.PNG nonchemical
# EP2947093A1_00002.PNG nonchemical
# EP2947093A1_00003.PNG nonchemical
# EP2947093A1_00004.PNG nonchemical
# EP2947093A1_00005.PNG nonchemical
# EP2947093A1_00006.PNG nonchemical
# EP2947093A1_00007.PNG nonchemical
# EP2947093A1_00008.PNG nonchemical
# EP2947093A1_00009.PNG nonchemical
# EP2947093A1_00010.PNG nonchemical
# EP2947093A1_00011.PNG nonchemical
# EP2947093A1_00012.PNG nonchemical
# EP2947093A1_00013.PNG nonchemical
# EP2947093A1_00014.PNG nonchemical
# EP2947093A1_00015.PNG nonchemical
# EP2947093A1_00016.PNG nonchemical
# EP2947093A1_00017.PNG nonchemical
# EP2947093A1_00018.PNG nonchemical
# EP2947093A1_00019.PNG nonchemical
# EP2947093A1_00020.PNG nonchemical
# EP2947093A1_00021.PNG nonchemical
# EP2947093A1_00022.PNG nonchemical
# EP2947093A1_00023.PNG nonchemical
# EP2947093A1_00024.PNG nonchemical
# EP2947093A1_00025.PNG nonchemical
# EP2947093A1_00026.PNG nonchemical
# EP2947093A1_00027.PNG nonchemical
# EP2947093A1_00028.PNG nonchemical
# EP2947093A1_00029.PNG nonchemical
# EP2947093A1_00030.PNG nonchemical
# EP2947093A1_00031.PNG nonchemical
# EP2947093A1_00032.PNG nonchemical
# EP2947093A1_00033.PNG nonchemical
# EP2947093A1_00034.PNG nonchemical
# EP2947093A1_00035.PNG nonchemical
# EP2947093A1_00036.PNG nonchemical
# EP2947093A1_00037.PNG nonchemical
# EP2947093A1_00038.PNG nonchemical
# EP2947093A1_00039.PNG nonchemical
# EP2947093A1_00040.PNG nonchemical
# EP2947093A1_00041.PNG nonchemical
# EP2947093A1_00042.PNG nonchemical
# EP2947093A1_00043.PNG nonchemical
# EP2947093A1_00044.PNG nonchemical
# EP2947093A1_00045.PNG nonchemical
# EP2947093A1_00046.PNG nonchemical
# EP2947093A1_00047.PNG nonchemical
# EP2947093A1_00048.PNG nonchemical
# EP2947093A1_00049.PNG nonchemical
# EP2947093A1_00050.PNG nonchemical
# EP2947093A1_00051.PNG nonchemical
# EP2947093A1_00052.PNG nonchemical
# EP2947093A1_00053.PNG nonchemical
# EP2947093A1_00054.PNG nonchemical
# EP2947093A1_00055.PNG nonchemical
# EP2947093A1_00056.PNG nonchemical
# EP2947093A1_00057.PNG nonchemical
# EP2947093A1_00058.PNG nonchemical
# EP2947093A1_00059.PNG nonchemical
# EP2947093A1_00060.PNG nonchemical
# EP2947093A1_00061.PNG nonchemical
# EP2947093A1_00062.PNG nonchemical
# EP2947093A1_00063.PNG nonchemical
# EP2947093A1_00064.PNG nonchemical
# EP2947093A1_00065.PNG nonchemical
# EP2947093A1_00066.PNG nonchemical
# EP2947093A1_00067.PNG nonchemical
# EP2947093A1_00068.PNG nonchemical
# EP2947093A1_00069.PNG nonchemical
# EP2947093A1_00070.PNG nonchemical
# EP2947093A1_00071.PNG nonchemical
# EP2947093A1_00072.PNG nonchemical
# EP2947093A1_00073.PNG nonchemical
# EP2947093A1_00074.PNG nonchemical
# EP2947093A1_00075.PNG nonchemical
# EP2947093A1_00076.PNG nonchemical
# EP2947093A1_00077.PNG nonchemical
# EP2947093A1_00078.PNG nonchemical
# EP2947093A1_00079.PNG nonchemical
# EP2947093A1_00080.PNG nonchemical
# EP2947093A1_00081.PNG nonchemical
# EP2947093A1_00082.PNG nonchemical
# EP2947093A1_00083.PNG nonchemical
# EP2947093A1_00084.PNG nonchemical
# EP2947093A1_00085.PNG nonchemical
# EP2947093A1_00086.PNG nonchemical
# EP2947093A1_00087.PNG nonchemical
# EP2947093A1_00088.PNG nonchemical
# EP2947093A1_00089.PNG nonchemical
# EP2947093A1_00090.PNG nonchemical
# EP2947093A1_00091.PNG nonchemical
# EP2947093A1_00092.PNG nonchemical
# EP2947093A1_00093.PNG nonchemical
# EP2947093A1_00094.PNG nonchemical
# EP2947093A1_00095.PNG nonchemical
# EP2947093A1_00096.PNG nonchemical
# EP2947093A1_00097.PNG nonchemical
# EP2947093A1_00098.PNG nonchemical
# EP2947093A1_00099.PNG nonchemical
# EP2947093A1_00100.PNG nonchemical
# EP2947093A1_00101.PNG nonchemical
# EP2947093A1_00102.PNG nonchemical
# EP2947093A1_00103.PNG nonchemical
# EP2947093A1_00104.PNG nonchemical
# EP2947093A1_00105.PNG nonchemical
# EP2947093A1_00106.PNG nonchemical
# EP2947093A1_00107.PNG nonchemical
# EP2947093A1_00108.PNG nonchemical
# EP2947093A1_00109.PNG nonchemical
# EP2947093A1_00110.PNG nonchemical
# EP2947093A1_00111.PNG nonchemical
# EP2947093A1_00112.PNG nonchemical
# EP2947093A1_00113.PNG nonchemical
# EP2947093A1_00114.PNG nonchemical
# EP2947093A1_00115.PNG nonchemical
# EP2947093A1_00116.PNG nonchemical
# EP2947093A1_00117.PNG nonchemical
# EP2947093A1_00118.PNG nonchemical
# EP2947093A1_00119.PNG nonchemical
# EP2947093A1_00120.PNG nonchemical
# EP2947093A1_00121.PNG nonchemical
# EP2947093A1_00122.PNG nonchemical
# EP2947093A1_00123.PNG nonchemical
# EP2947093A1_00124.PNG nonchemical
# EP2947093A1_00125.PNG nonchemical
# EP2947093A1_00126.PNG nonchemical
# EP2947093A1_00127.PNG nonchemical
# EP2947093A1_00128.PNG nonchemical
# EP2947093A1_00129.PNG nonchemical
# EP2947093A1_00130.PNG nonchemical
# EP2947093A1_00131.PNG nonchemical
# EP2947093A1_00132.PNG nonchemical
# EP2947093A1_00133.PNG nonchemical
# EP2947093A1_00134.PNG nonchemical
# EP2947093A1_00135.PNG nonchemical
# EP2947093A1_00136.PNG nonchemical
# EP2947093A1_00137.PNG nonchemical
# EP2947093A1_00138.PNG nonchemical
# EP2947093A1_00139.PNG nonchemical
# EP2947093A1_00140.PNG chemical
# EP2947093A1_00141.PNG chemical
# EP2947093A1_00142.PNG nonchemical
# EP2947093A1_00143.PNG chemical
# EP2947093A1_00144.PNG nonchemical
# EP2947093A1_00145.PNG nonchemical
# EP2947093A1_00146.PNG nonchemical
# EP2947093A1_00147.PNG nonchemical
# EP2947093A1_00148.PNG nonchemical
# EP2947093A1_00149.PNG nonchemical
# EP2947093A1_00150.PNG nonchemical
# EP2947093A1_00151.PNG nonchemical
# EP2947093A1_00152.PNG nonchemical
# EP2947093A1_00153.PNG nonchemical
# EP2947093A1_00154.PNG nonchemical
# EP2947093A1_00155.PNG nonchemical
# EP2947093A1_00156.PNG nonchemical
# EP2947093A1_00157.PNG nonchemical
# EP2947093A1_00158.PNG nonchemical
# EP2947093A1_00159.PNG nonchemical
# EP2947093A1_00160.PNG nonchemical
# EP2947093A1_00161.PNG nonchemical
# EP2947093A1_00162.PNG nonchemical
# EP2947093A1_00163.PNG nonchemical
# EP2947093A1_00164.PNG nonchemical
# EP2947093A1_00165.PNG nonchemical
# EP2947093A1_00166.PNG nonchemical
# EP2947093A1_00167.PNG nonchemical
# EP2947093A1_00168.PNG nonchemical
# EP2947093A1_00169.PNG nonchemical
# EP2947093A1_00170.PNG nonchemical
# EP2947093A1_00171.PNG nonchemical
# EP2947093A1_00172.PNG nonchemical
# EP2947093A1_00173.PNG nonchemical
# EP2947093A1_00174.PNG nonchemical
# EP2947093A1_00175.PNG nonchemical
# EP2947093A1_00176.PNG nonchemical
# EP2947093A1_00177.PNG nonchemical
# EP2947093A1_00178.PNG nonchemical
# EP2947093A1_00179.PNG nonchemical
# EP2947093A1_00180.PNG nonchemical
# EP2947093A1_00181.PNG nonchemical
# EP2947093A1_00182.PNG nonchemical
# EP2947093A1_00183.PNG nonchemical
# EP2947093A1_00184.PNG nonchemical
# EP2947093A1_00185.PNG nonchemical
# EP2947093A1_00186.PNG nonchemical
# EP2947093A1_00187.PNG nonchemical
# EP2947093A1_00188.PNG nonchemical
# EP2947093A1_00189.PNG nonchemical
# EP2947093A1_00190.PNG nonchemical
# EP2947093A1_00191.PNG nonchemical
# EP2947093A1_00192.PNG nonchemical
# EP2947093A1_00193.PNG nonchemical
# EP2947093A1_00194.PNG nonchemical
# EP2947093A1_00195.PNG nonchemical
# EP2947093A1_00196.PNG nonchemical
# EP2947093A1_00197.PNG nonchemical
# EP2947093A1_00198.PNG nonchemical
# EP2947093A1_00199.PNG nonchemical
# EP2947093A1_00200.PNG nonchemical
# EP2947093A1_00201.PNG nonchemical
# EP2947093A1_00202.PNG nonchemical
# EP2947093A1_00203.PNG nonchemical
# EP2947093A1_00204.PNG nonchemical
# EP2947093A1_00205.PNG nonchemical
# EP2947093A1_00206.PNG nonchemical
# EP2947093A1_00207.PNG nonchemical
# EP2947093A1_00208.PNG nonchemical
# EP2947093A1_00209.PNG nonchemical
# EP2947093A1_00210.PNG nonchemical
# EP2947093A1_00211.PNG nonchemical
# EP2947093A1_00212.PNG nonchemical
# EP2947093A1_00213.PNG nonchemical
# EP2947093A1_00214.PNG nonchemical
# EP2947093A1_00215.PNG nonchemical
# EP2947093A1_00216.PNG nonchemical
# EP2947093A1_00217.PNG nonchemical
# EP2947093A1_00218.PNG nonchemical
# EP2947093A1_00219.PNG nonchemical
# EP2947093A1_00220.PNG nonchemical
# EP2947093A1_00221.PNG nonchemical
# EP2947093A1_00222.PNG nonchemical
# EP2947093A1_00223.PNG nonchemical
# EP2947093A1_00224.PNG nonchemical
# EP2947093A1_00225.PNG nonchemical
# EP2947093A1_00226.PNG nonchemical
# EP2947093A1_00227.PNG nonchemical
# EP2947093A1_00228.PNG nonchemical
# EP2947093A1_00229.PNG nonchemical
# EP2947093A1_00230.PNG nonchemical
# EP2947093A1_00231.PNG nonchemical
# EP2947093A1_00232.PNG nonchemical
# EP2947093A1_00233.PNG nonchemical
# EP2947093A1_00234.PNG nonchemical
# EP2947093A1_00235.PNG nonchemical
# EP2947093A1_00236.PNG nonchemical
# EP2947093A1_00237.PNG nonchemical
# EP2947093A1_00238.PNG nonchemical
# EP2947093A1_00239.PNG nonchemical
# EP2947093A1_00240.PNG nonchemical
# EP2947093A1_00241.PNG nonchemical
# EP2947093A1_00242.PNG nonchemical
# EP2947093A1_00243.PNG nonchemical
